# %% [markdown]
# <a href="https://colab.research.google.com/github/Hrushikeshkhedkar123/4_Problems/blob/main/4_Problems/1_02.1_Python%20Terms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_02.1_Python Terms.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Example of Object (1.2.1.1)

# %%
python
x = "Hello, World!" # x is a string object
print(type(x))

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Define Variable (1.2.1.2)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Define Function (1.2.1.3)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Define Class (1.2.1.4)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Call Method (1.2.1.5)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Example of Attribute (1.2.1.6)

# %% [markdown]
# ---
